# %%
print('hello world')
# Out:
# hello world

# %%
age = 35
type(age)
# Out:
# int

# %%
heigh = 5.11
print(type(heigh))
# Out:
# <class 'float'>

# %%
name = "sami"
print(type(name))
# Out:
# <class 'str'>

# %%
# boolean datatype
is_true = True
print(type(is_true))
# Out:
# <class 'bool'>

# %%
a = 10;b=23
# a==b
type(a==b)
# Out:
# bool

# %%
result = "hello"+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result = "hello"+5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "hello"+' '+str(5)
print(result)
# Out:
# hello 5
