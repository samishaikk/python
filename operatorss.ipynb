# %%
print('hello world')
# Out:
# hello world

# %%
a = 34; b = 45

# arithmetic operators

print(f'addition is {a + b}')
print(f'subtraction is {a - b}')
print(f'multiplication is {a * b}')
print(f'division is {a / b}')
print(f'modulus is {a % b}')
print(f'floor division is {a // b}')
print(f'exponent is {a ** b}')
# Out:
# addition is 79
# subtraction is -11
# multiplication is 1530
# division is 0.7555555555555555
# modulus is 34
# floor division is 0
# exponent is 825184889837725994971915471173621692744697928074424045623011467853824

# %%
# basic calculator

num1 = int(input('enter first number: '))
num2 = int(input('enter second number: '))
op = input('enter operator: ')
if op == '+':
    print(f'addition is {num1 + num2}')
elif op == '-':
    print(f'subtraction is {num1 - num2}')
elif op == '*':
    print(f'multiplication is {num1 * num2}')
elif op == '/':
    print(f'division is {num1 / num2}')
elif op == '%':
    print(f'modulus is {num1 % num2}')
# Out:
# addition is 66

# %%
Str1 ="sami"
Str2 = "Sami"

if Str1 == Str2:
    print("both are equal")
else:
    print("both are not equal")
    
Str1==Str2 
# Str1!=Str2
# Out:
# both are not equal
# False

# %%
# assignment operators
x = 5
x += 3
x -= 2
x *= 2
x /= 2
x %= 2
x //= 2
x **= 2

# %% [markdown]
# ### logical operators

# %%
X = True; Y = False
print(X and Y)
print(X or Y)
print(not X)   
print(X ^ Y)  # xor
# Out:
# False
# True
# False
# True
