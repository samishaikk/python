# %%
# Naming conventions
# Variable names should start with a letter or underscore, followed by letters, digits, or underscores. 
# They are case-sensitive and cannot be Python reserved keywords.

first_name = "John"
last_name = "Doe"

# %%
# invalid variable names

1st_name = "Alice"  # Starts with a digit
@name = "Bob"     # Contains special character '@'
# Out:
#   Cell In[12], line 3
#     1st_name = "Alice"  # Starts with a digit
#     ^
# SyntaxError: invalid decimal literal

# %%
# understanding variable types
# python is a dynamically typed language
a = 10; name = "sami";c=3.14
type(a), type(name), type(c)
# Out:
# (int, str, float)

# %%
# type conversions
a = 34
print(type(a))
a_str=str(a)
print(type(a_str))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = '25'
print(type(age))
age_int = int(age)
print(type(age_int))
# Out:
# <class 'str'>
# <class 'int'>

# %%
name = 'sami'
age_int = int(age)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 name = 'sami'
# ----> 2 age_int = int(age)
#
# ValueError: invalid literal for int() with base 10: 'sami'

# %%
height = 5.11
type(height)
height_int = int(height)
print(type(height_int))
print(height_int)
# Out:
# <class 'int'>
# 5

# %%
# dynamic typing
var = 10
print(var, type(var))
var = "Hello"
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>

# %%
# input

age = input("Enter your age: ")
print("Your age is:", age)
print(type(age))
# Out:
# Your age is: 45
# <class 'str'>

# %%
num1 = input("Enter first number: ")
num2 = input("Enter second number: ")

sum = int(num1) + int(num2)
print("The sum is:", sum)
# Out:
# The sum is: 67
